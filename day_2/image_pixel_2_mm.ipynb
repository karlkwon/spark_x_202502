# %%
import cv2
from matplotlib import pyplot as plt

# %%
import math

# %%
# %matplotlib inline

# %%
img_path = "./20250122_sample.png"

# %%
img_color = cv2.imread(img_path)
# img_color = cv2.line(img_color, (25, 90), (1275, 82), (0, 255, 255), 1)
img_color = cv2.line(img_color, (200, 422), (1210, 420), (0, 0, 255), 2)

# %%
plt.figure(figsize=(12,6))
plt.imshow(cv2.cvtColor(img_color, cv2.COLOR_BGR2RGB))
plt.show()

# %%
img_color.shape
# Out:
# (678, 1274, 3)

# %%
# dx = 1275 - 25
# dy = 82 - 90
dx = 1210 - 200
dy = 420 - 422
print(dx, dy)
# Out:
# 1010 -2

# %%
math.sqrt(dx**2 + dy**2)
# Out:
# 1010.0019801960786

# %%
150/1010
# Out:
# 0.1485148514851485

# %%
img_path = "./20250122_sample2.png"

# %%
img_color = cv2.imread(img_path)
# img_color = cv2.line(img_color, (25, 90), (1275, 82), (0, 255, 255), 1)
img_color = cv2.line(img_color, (40, 522), (1020, 460), (0, 0, 255), 2)

# %%
plt.figure(figsize=(12,6))
plt.imshow(cv2.cvtColor(img_color, cv2.COLOR_BGR2RGB))
plt.show()

# %%
dx = 1020 - 40
dy = 460 - 522
print(dx, dy)
math.sqrt(dx**2 + dy**2)
# Out:
# 980 -62
# 981.9592659576058

# %%
150/982
# Out:
# 0.15274949083503056
